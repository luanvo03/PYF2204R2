# %%
usd = float(input("Nhập số tiền USD cần đổi: "))
tgia = float(input("Nhập tỉ giá USD/VND: "))
vnd = usd * tgia
print("{} USD = {} VND".format(usd, vnd))
# Out:
# Nhập số tiền USD cần đổi: 500
# Nhập tỉ giá USD/VND: 23000
# 500.0 USD = 11500000.0 VND
