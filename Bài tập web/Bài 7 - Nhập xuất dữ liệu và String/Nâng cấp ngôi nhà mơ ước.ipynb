# %%
import turtle
house = turtle.Turtle()
# house.speed(0)
house.pensize(2)
house.color("blue")
house.begin_fill()
house.hideturtle()
house.penup()
house.bk(125)
house.pendown()
for i in range(2):
    house.fd(250)
    house.lt(90)
    house.fd(100)
    house.lt(90)
house.penup()
house.fd(100)
house.pendown()
house.lt(90)
house.fd(70)
house.rt(90)
house.fd(50)
house.rt(90)
house.fd(70)
house.rt(90)
house.penup()
house.fd(150)
house.rt(90)
house.fd(100)
house.pendown()
house.rt(46)
house.fd(120)
house.rt(88)
house.fd(120)
house.rt(180)
house.penup()
house.fd(50)
house.pendown()
house.rt(46)
house.fd(40)
house.lt(90)
house.fd(20)
house.lt(90)
house.fd(20)
house.rt(180)
house.penup()
house.fd(40)
house.rt(90)
house.fd(5)
house.lt(90)
house.pendown()
house.fd(20)
house.penup()
house.rt(90)
house.fd(10)
house.lt(90)
house.fd(5)
house.rt(180)
house.pendown()
house.fd(30)
